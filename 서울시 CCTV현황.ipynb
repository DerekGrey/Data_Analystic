# %%
import numpy as np #수학과 관련된 간단한 계산, random값, 상관계수

# %%
import pandas as pd

# %%
CCTV_seoul = pd.read_csv('../data/01. CCTV_in_Seoul.csv', encoding='utf-8')

# %%
CCTV_seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_seoul.rename(columns={CCTV_seoul.columns[0]:'구별'}, inplace=True)

# %%
CCTV_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
pop_Seoul = pd.read_excel('../data/01. population_in_Seoul.xls',
                          header = 2,
                          usecols = 'B, D, G, J, N',
                          encoding =  'utf-8'
                          )

# %%
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
CCTV_seoul.sort_values(by = '소계', ascending=True).head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  485        238    159     42    386
# 12  마포구  574        314    118    169    379
# 17  송파구  618        529     21     68    463
# 24  중랑구  660        509    121    177    109
# 23   중구  671        413    190     72    348

# %%
CCTV_seoul.sort_values('소계', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_Seoul.sort_values(by='계', ascending=False).head()
# Out:
#     자치구           계        계.1       계.2   65세이상고령자
# 0    합계  10197604.0  9926968.0  270636.0  1321458.0
# 24  송파구    667483.0   660584.0    6899.0    72506.0
# 16  강서구    603772.0   597248.0    6524.0    72548.0
# 23  강남구    570500.0   565550.0    4950.0    63167.0
# 11  노원구    569384.0   565565.0    3819.0    71941.0

# %%
pop_Seoul.rename(columns={
                pop_Seoul.columns[0] : '구별',
                pop_Seoul.columns[1] : '인구수',
                pop_Seoul.columns[2] : '한국인',
                pop_Seoul.columns[3] : '외국인',
                pop_Seoul.columns[4] : '고령자'
    }, inplace=True)

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_Seoul.tail()
# Out:
#      구별       인구수       한국인     외국인      고령자
# 22  서초구  450310.0  445994.0  4316.0  51733.0
# 23  강남구  570500.0  565550.0  4950.0  63167.0
# 24  송파구  667483.0  660584.0  6899.0  72506.0
# 25  강동구  453233.0  449019.0  4214.0  54622.0
# 26  NaN       NaN       NaN     NaN      NaN

# %%
# NaN: not a number, NA: Not Available

# %%
pop_Seoul.drop([0], inplace=True)
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
pop_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
pop_Seoul['구별'].isnull()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# Name: 구별, dtype: bool

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
pop_Seoul.drop([26], inplace=True)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100

# %%
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  11.342849

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100

# %%
pop_Seoul['한국인비율'] = pop_Seoul['한국인'] / pop_Seoul['인구수'] * 100

# %%
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자      고령자비율     외국인비율      한국인비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  15.615404  5.669451  94.330549
# 2   중구  133240.0  124312.0   8928.0  20764.0  15.583909  6.700690  93.299310
# 3  용산구  244203.0  229456.0  14747.0  36231.0  14.836427  6.038828  93.961172
# 4  성동구  311244.0  303380.0   7864.0  39997.0  12.850689  2.526635  97.473365
# 5  광진구  372164.0  357211.0  14953.0  42214.0  11.342849  4.017852  95.982148

# %%
pop_Seoul.sort_values(by='외국인비율', ascending=False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자      고령자비율     외국인비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  13.006191  8.663598
# 18   금천구  255082.0  236353.0  18729.0  32970.0  12.925255  7.342345
# 17   구로구  447874.0  416487.0  31387.0  56833.0  12.689506  7.007998
# 2     중구  133240.0  124312.0   8928.0  20764.0  15.583909  6.700690
# 3    용산구  244203.0  229456.0  14747.0  36231.0  14.836427  6.038828

# %%
pop_Seoul.sort_values(by='고령자비율', ascending=False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자      고령자비율     외국인비율
# 9    강북구  330192.0  326686.0   3506.0  54813.0  16.600342  1.061806
# 1    종로구  162820.0  153589.0   9231.0  25425.0  15.615404  5.669451
# 2     중구  133240.0  124312.0   8928.0  20764.0  15.583909  6.700690
# 3    용산구  244203.0  229456.0  14747.0  36231.0  14.836427  6.038828
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  14.720797  3.723221

# %%
CCTV_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_seoul['최근증가율'] = (CCTV_seoul['2016년'] +
                            CCTV_seoul['2015년'] +
                            CCTV_seoul['2014년']               
                           ) / CCTV_seoul['2013년도 이전'] * 100

# %%
CCTV_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  2780       1292    430    584    932  150.619195
# 1  강동구   773        379     99    155    377  166.490765
# 2  강북구   748        369    120    138    204  125.203252
# 3  강서구   884        388    258    184     81  134.793814
# 4  관악구  1496        846    260    390    613  149.290780

# %%
CCTV_seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
data_result = pd.merge(CCTV_seoul, pop_Seoul, on='구별') #열병합

# %%
data_result.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인      고령자      고령자비율     외국인비율      한국인비율
# 0   4950.0  63167.0  11.072217  0.867660  99.132340
# 1   4214.0  54622.0  12.051638  0.929765  99.070235
# 2   3506.0  54813.0  16.600342  1.061806  98.938194
# 3   6524.0  72548.0  12.015794  1.080540  98.919460
# 4  18312.0  68082.0  12.955291  3.484582  96.515418

# %%
del data_result['2013년도 이전'] #열삭제
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']

# %%
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자      고령자비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  11.072217
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  12.051638
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  16.600342
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  12.015794
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  12.955291
#
#       외국인비율      한국인비율
# 0  0.867660  99.132340
# 1  0.929765  99.070235
# 2  1.061806  98.938194
# 3  1.080540  98.919460
# 4  3.484582  96.515418

# %%
data_result.set_index('구별', inplace=True)

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자      고령자비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  11.072217
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  12.051638
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  16.600342
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  12.015794
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  12.955291
#
#         외국인비율      한국인비율
# 구별
# 강남구  0.867660  99.132340
# 강동구  0.929765  99.070235
# 강북구  1.061806  98.938194
# 강서구  1.080540  98.919460
# 관악구  3.484582  96.515418

# %%
#두 항목간의 상관관계가 있는지 수치를 계산, 상관계수(-1 ~ +1)
#0: 상관없음. 3: 약한 상관, 7: 강한 상관
np.corrcoef(data_result['고령자비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.28078554],
#        [-0.28078554,  1.        ]])

# %%
np.corrcoef(data_result['외국인비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.13607433],
#        [-0.13607433,  1.        ]])

# %%
np.corrcoef(data_result['인구수'], data_result['소계'])
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
plt.figure()
# x축은 index로 기본 설정됨.
data_result['소계'].plot(kind='barh', grid=True, figsize=(10, 10))

plt.show()

# %%
plt.figure()

data_result['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10, 10), )

plt.show()

# %%
plt.figure(figsize = (10, 10))

plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV 소계')
plt.grid()
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

# %%
fp1 #array([1.30916415e-03, 6.45066497e+02]): 기울기 + 절편
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
fx = np.linspace(100000, 700000, 100)
fy = np.poly1d(fp1)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV 소계')
plt.grid()


plt.plot(fx, fy(fx), ls='dashed', lw=3, color='r')

plt.show()

# %%
plt.figure(figsize=(15, 15))

plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV 소계')
plt.grid()


plt.plot(fx, fy(fx), ls='dashed', lw=3, color='r')

for n in range(25):
    plt.text(data_result['인구수'][n]*1.02, 
            data_result['소계'][n]*0.98,
             data_result.index[n], fontsize=20
            )

plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000)
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)

plt.figure(figsize=(10,6))
plt.plot(s1, label='s1')
plt.plot(s2, label='s2')
plt.plot(s3, label='s3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((data_result['인구수']))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((data_result['외국인비율'], data_result['한국인비율'], data_result['고령자비율']))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((data_result['외국인비율'],data_result['고령자비율']))
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10, 10))

plt.scatter(data_result['인구수'], data_result['고령자비율'], s=50)
plt.xlabel('인구수')
plt.ylabel('고령자비율')
plt.grid()
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
