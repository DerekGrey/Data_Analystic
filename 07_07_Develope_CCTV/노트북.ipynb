# %%
import pandas as pd
import numpy as np

# %%
crime_anal_police = pd.read_csv("crime_in_Seoul_include_gu_name.csv",
                               thousands=',',
                                encoding='utf-8'
                               )

# %% [markdown]
# * thousands <-- 천단위에 , 가 있으니까 그걸 제거하고 가져와줘!

# %%
crime_anal_police
# Out:
#     Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0            0   중부서      2      2      3      2    105     65   1395    477
# 1            1   종로서      3      3      6      5    115     98   1070    413
# 2            2  남대문서      1      0      6      4     65     46   1153    382
# 3            3  서대문서      2      2      5      4    154    124   1812    738
# 4            4   혜화서      3      2      5      4     96     63   1114    424
# 5            5   용산서      5      5     14     14    194    173   1557    587
# 6            6   성북서      2      2      2      1     86     71    953    409
# 7            7  동대문서      5      5     13     13    173    146   1981    814
# 8            8   마포서      8      8     14     10    294    247   2555    813
# 9            9  영등포서     14     12     22     20    295    183   2964    978
# 10          10   성동서      4      4      9      8    126    119   1607    597
# ...

# %%
# !pip install googlemaps
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
# ...

# %%
import googlemaps

# %%
gmaps_key = 'AIzaSyCxF9p0e18rdjf1MXyTVK3evaKUeRXmFG0'
gmaps = googlemaps.Client(key=gmaps_key)

# %%
gmaps.geocode('중부경찰서', language='ko')
# Out:
# [{'address_components': [{'long_name': '２７',
#     'short_name': '２７',
#     'types': ['premise']},
#    {'long_name': '수표로',
#     'short_name': '수표로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '을지로동',
#     'short_name': '을지로동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-032',
#     'short_name': '100-032',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 을지로동 수표로 27',
#   'geometry': {'location': {'lat': 37.5636465, 'lng': 126.9895796},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.56499548029149,
# ...

# %%
gmaps.geocode('신촌역', language='ko')
# Out:
# [{'address_components': [{'long_name': '신촌',
#     'short_name': '신촌',
#     'types': ['establishment',
#      'point_of_interest',
#      'subway_station',
#      'transit_station']},
#    {'long_name': '신촌동',
#     'short_name': '신촌동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '120-140',
#     'short_name': '120-140',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 신촌동 신촌',
#   'geometry': {'location': {'lat': 37.559778, 'lng': 126.942325},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 37.5611269802915,
#      'lng': 126.9436739802915},
#     'southwest': {'lat': 37.55842901970851, 'lng': 126.9409760197085}}},
#   'place_id': 'ChIJ0RGmEpCYfDURAziCwM4_WcU',
# ...

# %%
gmaps.geocode('더조은 컴퓨터아카데미 신촌점', language='ko')
# Out:
# [{'address_components': [{'long_name': '마포구',
#     'short_name': '마포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '노고산동',
#     'short_name': '노고산동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '121-100',
#     'short_name': '121-100',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 마포구 노고산동 57-1',
#   'geometry': {'location': {'lat': 37.5549035, 'lng': 126.9360342},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 37.5562524802915,
#      'lng': 126.9373831802915},
#     'southwest': {'lat': 37.55355451970851, 'lng': 126.9346852197085}}},
#   'place_id': 'ChIJ4XNdl5WYfDURLSD0rRqSVWI',
# ...

# %% [markdown]
# * 값은 리스트 안에 딕셔너리 값으로 온다 => 딕셔너리 리스트

# %% [markdown]
# * 중부서 라고 하면 값이 나오지 않는다 그래서 관서명의 열에서 '중부서'의 서를 제거하고 앞에는 '서울' 뒤에는'경찰서'를 붙인다

# %%
station_name = []

for name in crime_anal_police['관서명']:
    station_name.append('서울'+name[:-1] +'경찰서')
    
station_name
# Out:
# ['서울중부경찰서',
#  '서울종로경찰서',
#  '서울남대문경찰서',
#  '서울서대문경찰서',
#  '서울혜화경찰서',
#  '서울용산경찰서',
#  '서울성북경찰서',
#  '서울동대문경찰서',
#  '서울마포경찰서',
#  '서울영등포경찰서',
#  '서울성동경찰서',
#  '서울동작경찰서',
#  '서울광진경찰서',
#  '서울서부경찰서',
#  '서울강북경찰서',
#  '서울금천경찰서',
#  '서울중랑경찰서',
#  '서울강남경찰서',
#  '서울관악경찰서',
#  '서울강서경찰서',
#  '서울강동경찰서',
#  '서울종암경찰서',
#  '서울구로경찰서',
#  '서울서초경찰서',
#  '서울양천경찰서',
#  '서울송파경찰서',
#  '서울노원경찰서',
#  '서울방배경찰서',
#  '서울은평경찰서',
#  '서울도봉경찰서',
#  '서울수서경찰서']

# %% [markdown]
# * 리스트 [: ] 이렇게 하면 처음부터 끝까지 [ : -1 ] 이면 끝값에서 -1 값을 한 것이 된다.

# %%
# 각 경찰서 별 전체 주소 리스트
# 각 경찰서 별 위도 리스트
# 각 경찰서 별 경도 리스트
station_address = []
station_lat =[]
station_lng = []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    station_address.append(tmp[0].get('formatted_address'))
    tmp_loc = tmp[0].get('geometry')
    
    station_lat.append(tmp_loc['location']['lat'])
    station_lng.append(tmp_loc['location']['lng'])
    
    print(name + '  ---> ' + tmp[0].get('formatted_address') +'  위도'+ str(tmp_loc['location']['lat']) + '  경도'+str(tmp_loc['location']['lng']))
# Out:
# 서울중부경찰서  ---> 대한민국 서울특별시 중구 을지로동 수표로 27  위도37.5636465  경도126.9895796
# 서울종로경찰서  ---> 대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46  위도37.5755578  경도126.9848674
# 서울남대문경찰서  ---> 대한민국 서울특별시 중구 회현동 한강대로 410  위도37.5547584  경도126.9734981
# 서울서대문경찰서  ---> 대한민국 서울특별시 서대문구 충현동 통일로 113  위도37.5647848  경도126.9667762
# 서울혜화경찰서  ---> 대한민국 서울특별시 종로구 인의동 창경궁로 112-16  위도37.5718529  경도126.9989143
# 서울용산경찰서  ---> 대한민국 서울특별시 용산구 원효로1가 백범로 329  위도37.5387099  경도126.9659183
# 서울성북경찰서  ---> 대한민국 서울특별시 성북구 삼선동5가 301  위도37.5897482  경도127.0161353
# 서울동대문경찰서  ---> 대한민국 서울특별시 동대문구 청량리동 약령시로21길 29  위도37.58506149999999  경도127.0457679
# 서울마포경찰서  ---> 대한민국 서울특별시 마포구 아현동 마포대로 183  위도37.550814  경도126.954028
# 서울영등포경찰서  ---> 대한민국 서울특별시 영등포구 영등포동1가 618-7  위도37.5153176  경도126.905728
# 서울성동경찰서  ---> 대한민국 서울특별시 성동구 행당동 왕십리광장로 9  위도37.5617309  경도127.0363806
# 서울동작경찰서  ---> 대한민국 서울특별시 동작구 노량진1동 노량진로 148  위도37.5130866  경도126.9428498
# 서울광진경찰서  ---> 대한민국 서울특별시 광진구 구의동 자양로 167  위도37.542873  경도127.083821
# ...

# %%
len(station_address)
# Out:
# 31

# %%
len(station_lat)
# Out:
# 31

# %%
len(station_lng)
# Out:
# 31

# %%
gu_name = []

for name in station_address:
    tmp = name.split()
    print(tmp)
# Out:
# ['대한민국', '서울특별시', '중구', '을지로동', '수표로', '27']
# ['대한민국', '서울특별시', '종로구', '종로1.2.3.4가동', '율곡로', '46']
# ['대한민국', '서울특별시', '중구', '회현동', '한강대로', '410']
# ['대한민국', '서울특별시', '서대문구', '충현동', '통일로', '113']
# ['대한민국', '서울특별시', '종로구', '인의동', '창경궁로', '112-16']
# ['대한민국', '서울특별시', '용산구', '원효로1가', '백범로', '329']
# ['대한민국', '서울특별시', '성북구', '삼선동5가', '301']
# ['대한민국', '서울특별시', '동대문구', '청량리동', '약령시로21길', '29']
# ['대한민국', '서울특별시', '마포구', '아현동', '마포대로', '183']
# ['대한민국', '서울특별시', '영등포구', '영등포동1가', '618-7']
# ['대한민국', '서울특별시', '성동구', '행당동', '왕십리광장로', '9']
# ['대한민국', '서울특별시', '동작구', '노량진1동', '노량진로', '148']
# ['대한민국', '서울특별시', '광진구', '구의동', '자양로', '167']
# ['대한민국', '서울특별시', '은평구', '신사2동', '184-56']
# ['대한민국', '서울특별시', '강북구', '번1동', '오패산로', '406']
# ['대한민국', '서울특별시', '금천구', '시흥동', '190']
# ['대한민국', '서울특별시', '중랑구', '망우동', '489-7']
# ['대한민국', '서울특별시', '강남구', '대치동', '998']
# ['대한민국', '서울특별시', '관악구', '봉천동']
# ['대한민국', '서울특별시', '강서구', '화곡6동', '980-15']
# ['대한민국', '서울특별시', '강동구', '성내1동', '성내로', '57']
# ...

# %%
gu_name = []

for name in station_address:
    tmp = name.split()
    #print(tmp)
    for x in tmp:
        if(x[-1] == '구'):
            gu_name.append(x)
gu_name
# Out:
# ['중구',
#  '종로구',
#  '중구',
#  '서대문구',
#  '종로구',
#  '용산구',
#  '성북구',
#  '동대문구',
#  '마포구',
#  '영등포구',
#  '성동구',
#  '동작구',
#  '광진구',
#  '은평구',
#  '강북구',
#  '금천구',
#  '중랑구',
#  '강남구',
#  '관악구',
#  '강서구',
#  '강동구',
#  '성북구',
#  '구로구',
#  '서초구',
#  '양천구',
#  '송파구',
#  '노원구',
#  '서초구',
#  '은평구',
#  '도봉구',
#  '강남구']

# %%
gu_name = []

for name in station_address:
    tmp = name.split()
    tmp_gu = [x for x in tmp if x[-1] == '구'][0]
    print(tmp_gu)
    gu_name.append(tmp_gu)
# Out:
# 중구
# 종로구
# 중구
# 서대문구
# 종로구
# 용산구
# 성북구
# 동대문구
# 마포구
# 영등포구
# 성동구
# 동작구
# 광진구
# 은평구
# 강북구
# 금천구
# 중랑구
# 강남구
# 관악구
# 강서구
# 강동구
# 성북구
# 구로구
# 서초구
# 양천구
# 송파구
# 노원구
# 서초구
# 은평구
# 도봉구
# 강남구

# %%
gu_name2= []

for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    gu_name2.append(tmp[0].get('address_components')[3].get('long_name'))
    

    
len(gu_name2)
# Out:
# 31

# %%
gum_name2 = []
a= 0
b= 0
print(len(station_name))
for name in station_name:
    tmp = gmaps.geocode(name, language='ko')
    print()
    b+=1
    print(b)
    print('tmp숫자')
    print(len(tmp))
    
    for x in tmp:
        print('--------시작-------------')
        a+=1
        print(a)
        print()
        tmp2 = x.get('address_components')
        
        
        for y in tmp2:
            z = y.get('long_name')
            print(z)
            
            if z[-1] =='구':
                print('--------')
                gum_name2.append(z)
                
len(gum_name2)

# 같은 이름을 가진 경철서가 두개 있다는 것을 알 수 있다!
# Out:
# 31
#
# 1
# tmp숫자
# 1
# --------시작-------------
# 1
#
# ２７
# 수표로
# 을지로동
# 중구
# --------
# 서울특별시
# 대한민국
# 100-032
#
# 2
# tmp숫자
# 1
# --------시작-------------
# 2
#
# ４６
# 율곡로
# 종로1.2.3.4가동
# 종로구
# --------
# 서울특별시
# 대한민국
# 110-310
#
# 3
# tmp숫자
# 1
# --------시작-------------
# 3
#
# ４１０
# 한강대로
# 회현동
# 중구
# --------
# 서울특별시
# 대한민국
# 100-095
#
# 4
# tmp숫자
# 1
# --------시작-------------
# 4
#
# １１３
# 통일로
# 충현동
# 서대문구
# --------
# 서울특별시
# 대한민국
# 120-020
#
# 5
# tmp숫자
# 1
# --------시작-------------
# 5
#
# １１２−１６
# 창경궁로
# 인의동
# 종로구
# --------
# 서울특별시
# 대한민국
# 110-410
#
# 6
# tmp숫자
# 2
# --------시작-------------
# 6
#
# ３２９
# 백범로
# 원효로1가
# 용산구
# --------
# 서울특별시
# 대한민국
# 140-111
# --------시작-------------
# 7
#
# ２４
# 원효로89길
# 원효로1가
# 용산구
# --------
# 서울특별시
# 대한민국
# 140-111
#
# 7
# tmp숫자
# 1
# --------시작-------------
# 8
#
# ３０１
# 삼선동5가
# 성북구
# --------
# 서울특별시
# 대한민국
# 136-045
#
# 8
# tmp숫자
# 1
# --------시작-------------
# 9
#
# ２９
# 약령시로21길
# 청량리동
# 동대문구
# --------
# 서울특별시
# 대한민국
# 130-010
#
# ...

# %%
crime_anal_police['구별'] = gu_name

# %%
crime_anal_police
# Out:
#     Unnamed: 0   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  \
# 0            0   중부서      2      2      3      2    105     65   1395    477
# 1            1   종로서      3      3      6      5    115     98   1070    413
# 2            2  남대문서      1      0      6      4     65     46   1153    382
# 3            3  서대문서      2      2      5      4    154    124   1812    738
# 4            4   혜화서      3      2      5      4     96     63   1114    424
# 5            5   용산서      5      5     14     14    194    173   1557    587
# 6            6   성북서      2      2      2      1     86     71    953    409
# 7            7  동대문서      5      5     13     13    173    146   1981    814
# 8            8   마포서      8      8     14     10    294    247   2555    813
# 9            9  영등포서     14     12     22     20    295    183   2964    978
# 10          10   성동서      4      4      9      8    126    119   1607    597
# ...

# %%
crime_anal_police.to_csv('crime_in_Seoul_include_gu_name.csv' , sep=',', encoding='utf-8')

# %%
crime_anal_raw = pd.read_csv('crime_in_Seoul_include_gu_name.csv', encoding='utf-8')

# %%
crime_anal_raw
# Out:
#     Unnamed: 0  Unnamed: 0.1   관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  \
# 0            0             0   중부서      2      2      3      2    105     65
# 1            1             1   종로서      3      3      6      5    115     98
# 2            2             2  남대문서      1      0      6      4     65     46
# 3            3             3  서대문서      2      2      5      4    154    124
# 4            4             4   혜화서      3      2      5      4     96     63
# 5            5             5   용산서      5      5     14     14    194    173
# 6            6             6   성북서      2      2      2      1     86     71
# 7            7             7  동대문서      5      5     13     13    173    146
# 8            8             8   마포서      8      8     14     10    294    247
# 9            9             9  영등포서     14     12     22     20    295    183
# 10          10            10   성동서      4      4      9      8    126    119
# ...

# %%
crime_anal = pd.pivot_table(crime_anal_raw, index='구별', aggfunc=np.sum) # 구별로 묶어줘~
crime_anal.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  \
# 구별
# 강남구          47            47    349    449     18     21     10     13
# 강동구          20            20    123    156      8      6      3      4
# 강북구          14            14    126    153     13     14      8      7
# 강서구          19            19    191    262     13     13      8      7
# 관악구          18            18    221    320     14     12      8      9
#
#      절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구   1650   3850   3705   4284
# 강동구    789   2366   2248   2712
# 강북구    618   1434   2348   2649
# 강서구   1260   2096   2718   3207
# 관악구    827   2706   2642   3298

# %%
crime_anal['강간검거율'] = crime_anal['강간 검거']/crime_anal['강간 발생']*100
crime_anal['강도검거율'] = crime_anal['강도 검거']/crime_anal['강도 발생']*100
crime_anal['살인검거율'] = crime_anal['살인 검거']/crime_anal['살인 발생']*100
crime_anal['절도검거율'] = crime_anal['절도 검거']/crime_anal['절도 발생']*100
crime_anal['폭력검거율'] = crime_anal['폭력 검거']/crime_anal['폭력 발생']*100

# %%
crime_anal.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  \
# 구별
# 강남구          47            47    349    449     18     21     10     13
# 강동구          20            20    123    156      8      6      3      4
# 강북구          14            14    126    153     13     14      8      7
# 강서구          19            19    191    262     13     13      8      7
# 관악구          18            18    221    320     14     12      8      9
#
#      절도 검거  절도 발생  폭력 검거  폭력 발생      강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구   1650   3850   3705   4284  77.728285   85.714286   76.923077  42.857143
# 강동구    789   2366   2248   2712  78.846154  133.333333   75.000000  33.347422
# 강북구    618   1434   2348   2649  82.352941   92.857143  114.285714  43.096234
# 강서구   1260   2096   2718   3207  72.900763  100.000000  114.285714  60.114504
# 관악구    827   2706   2642   3298  69.062500  116.666667   88.888889  30.561715
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# ...

# %%
del crime_anal['강간 검거']
del crime_anal['강도 검거']
del crime_anal['살인 검거']
del crime_anal['절도 검거']
del crime_anal['폭력 검거']
crime_anal.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생      강간검거율  \
# 구별
# 강남구          47            47    449     21     13   3850   4284  77.728285
# 강동구          20            20    156      6      4   2366   2712  78.846154
# 강북구          14            14    153     14      7   1434   2649  82.352941
# 강서구          19            19    262     13      7   2096   3207  72.900763
# 관악구          18            18    320     12      9   2706   3298  69.062500
#
#           강도검거율       살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   85.714286   76.923077  42.857143  86.484594
# 강동구  133.333333   75.000000  33.347422  82.890855
# 강북구   92.857143  114.285714  43.096234  88.637222
# 강서구  100.000000  114.285714  60.114504  84.752105
# 관악구  116.666667   88.888889  30.561715  80.109157

# %%
con_list = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
for column in con_list:
        crime_anal.loc[crime_anal[column] > 100, column] = 100
crime_anal.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0  Unnamed: 0.1  강간 발생  강도 발생  살인 발생  절도 발생  폭력 발생       강간검거율  \
# 구별
# 강남구           47            47    449     21     13   3850   4284   77.728285
# 강동구           20            20    156      6      4   2366   2712   78.846154
# 강북구           14            14    153     14      7   1434   2649   82.352941
# 강서구           19            19    262     13      7   2096   3207   72.900763
# 관악구           18            18    320     12      9   2706   3298   69.062500
# 광진구           12            12    240     14      4   3026   2625   91.666667
# 구로구           22            22    281     15      8   2335   3007   58.362989
# 금천구           15            15    151      6      3   1567   2054   80.794702
# 노원구           26            26    197      7     10   2193   2723   61.421320
# 도봉구           29            29    102      9      3   1063   1487  100.000000
# 동대문구           7             7    173     13      5   1981   2548   84.393064
# ...

# %%
crime_anal.rename(columns={
    '강간 발생' : '강간',
    '강도 발생' : '강도',
    '살인 발생' : '살인',
    '절도 발생' : '절도',
    '폭력 발생' : '폭력'
}, inplace=True)
crime_anal.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1   강간  강도  살인    절도    폭력      강간검거율       강도검거율  \
# 구별
# 강남구          47            47  449  21  13  3850  4284  77.728285   85.714286
# 강동구          20            20  156   6   4  2366  2712  78.846154  100.000000
# 강북구          14            14  153  14   7  1434  2649  82.352941   92.857143
# 강서구          19            19  262  13   7  2096  3207  72.900763  100.000000
# 관악구          18            18  320  12   9  2706  3298  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 강서구  100.000000  60.114504  84.752105
# 관악구   88.888889  30.561715  80.109157

# %%
del crime_anal['Unnamed: 0']
crime_anal.head()
# Out:
#      Unnamed: 0.1   강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구            47  449  21  13  3850  4284  77.728285   85.714286   76.923077
# 강동구            20  156   6   4  2366  2712  78.846154  100.000000   75.000000
# 강북구            14  153  14   7  1434  2649  82.352941   92.857143  100.000000
# 강서구            19  262  13   7  2096  3207  72.900763  100.000000  100.000000
# 관악구            18  320  12   9  2706  3298  69.062500  100.000000   88.888889
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
crime_anal.head()
# Out:
#      Unnamed: 0.1   강간  강도  살인    절도    폭력      강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구            47  449  21  13  3850  4284  77.728285   85.714286   76.923077
# 강동구            20  156   6   4  2366  2712  78.846154  100.000000   75.000000
# 강북구            14  153  14   7  1434  2649  82.352941   92.857143  100.000000
# 강서구            19  262  13   7  2096  3207  72.900763  100.000000  100.000000
# 관악구            18  320  12   9  2706  3298  69.062500  100.000000   88.888889
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
crime_anal
# Out:
#       Unnamed: 0.1   강간  강도  살인    절도    폭력       강간검거율       강도검거율  \
# 구별
# 강남구             47  449  21  13  3850  4284   77.728285   85.714286
# 강동구             20  156   6   4  2366  2712   78.846154  100.000000
# 강북구             14  153  14   7  1434  2649   82.352941   92.857143
# 강서구             19  262  13   7  2096  3207   72.900763  100.000000
# 관악구             18  320  12   9  2706  3298   69.062500  100.000000
# 광진구             12  240  14   4  3026  2625   91.666667  100.000000
# 구로구             22  281  15   8  2335  3007   58.362989   73.333333
# 금천구             15  151   6   3  1567  2054   80.794702  100.000000
# 노원구             26  197   7  10  2193  2723   61.421320  100.000000
# 도봉구             29  102   9   3  1063  1487  100.000000  100.000000
# 동대문구             7  173  13   5  1981  2548   84.393064  100.000000
# 동작구             11  285   9   5  1865  1910   48.771930   55.555556
# 마포구              8  294  14   8  2555  2983   84.013605   71.428571
# ...

# %%
from sklearn import preprocessing

col = ['강간','강도','살인','절도','폭력']

x = crime_anal[col].values
# 정해진 [] 의 값을 가져온다.(행열에 있는 것)

min_max_scaler = preprocessing.MinMaxScaler()
# 함수를 선언함 ( 0~ 1까지 나타내는 함수)


x_scaled = min_max_scaler.fit_transform(x.astype(float))
crime_anal_norm = pd.DataFrame(x_scaled, columns = col, index = crime_anal.index)

col2 = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm[col2] = crime_anal[col2]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077  42.857143  86.484594
# 강동구   75.000000  33.347422  82.890855
# 강북구  100.000000  43.096234  88.637222
# 강서구  100.000000  60.114504  84.752105
# 관악구   88.888889  30.561715  80.109157

# %%
min_max_scaler
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
result_CCTV = pd.read_csv("01. CCTV_result.csv", encoding='UTF-8', index_col='구별')
crime_anal_norm[['인구수','CCTV']] = result_CCTV[['인구수','소계']]
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780
# 강동구   75.000000  33.347422  82.890855  453233.0   773
# 강북구  100.000000  43.096234  88.637222  330192.0   748
# 강서구  100.000000  60.114504  84.752105  603772.0   884
# 관악구   88.888889  30.561715  80.109157  525515.0  1496

# %%
col = ['강간','강도','살인','절도','폭력']
crime_anal_norm['범죄'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.857843
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.286607
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.641616
# 강서구  100.000000  60.114504  84.752105  603772.0   884  2.333944
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.860342

# %%
col = ['강간검거율','강도검거율','살인검거율','절도검거율','폭력검거율']
crime_anal_norm['검거'] = np.sum(crime_anal_norm[col], axis=1)
crime_anal_norm.head()
# Out:
#            강간        강도        살인        절도        폭력      강간검거율       강도검거율  \
# 구별
# 강남구  1.000000  0.941176  0.916667  1.000000  1.000000  77.728285   85.714286
# 강동구  0.155620  0.058824  0.166667  0.467528  0.437969  78.846154  100.000000
# 강북구  0.146974  0.529412  0.416667  0.133118  0.415445  82.352941   92.857143
# 강서구  0.461095  0.470588  0.416667  0.370649  0.614945  72.900763  100.000000
# 관악구  0.628242  0.411765  0.583333  0.589523  0.647479  69.062500  100.000000
#
#           살인검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거
# 구별
# 강남구   76.923077  42.857143  86.484594  570500.0  2780  4.857843  369.707384
# 강동구   75.000000  33.347422  82.890855  453233.0   773  1.286607  370.084431
# 강북구  100.000000  43.096234  88.637222  330192.0   748  1.641616  406.943540
# 강서구  100.000000  60.114504  84.752105  603772.0   884  2.333944  417.767372
# 관악구   88.888889  30.561715  80.109157  525515.0  1496  2.860342  368.622261

# %%
crime_anal_norm
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  \
# 구별
# 강남구   1.000000  0.941176  0.916667  1.000000  1.000000   77.728285
# 강동구   0.155620  0.058824  0.166667  0.467528  0.437969   78.846154
# 강북구   0.146974  0.529412  0.416667  0.133118  0.415445   82.352941
# 강서구   0.461095  0.470588  0.416667  0.370649  0.614945   72.900763
# 관악구   0.628242  0.411765  0.583333  0.589523  0.647479   69.062500
# 광진구   0.397695  0.529412  0.166667  0.704342  0.406864   91.666667
# 구로구   0.515850  0.588235  0.500000  0.456405  0.543439   58.362989
# 금천구   0.141210  0.058824  0.083333  0.180840  0.202717   80.794702
# 노원구   0.273775  0.117647  0.666667  0.405454  0.441902   61.421320
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000
# 동대문구  0.204611  0.470588  0.250000  0.329386  0.379335   84.393064
# 동작구   0.527378  0.235294  0.250000  0.287765  0.151233   48.771930
# 마포구   0.553314  0.529412  0.500000  0.535343  0.534859   84.013605
# ...

# %% [markdown]
# ### 범죄율에 대한 지도 시각화

# %%
# !pip install folium
import folium
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
# ...

# %%
import json
geo_path = '02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='UTF-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, 
                 tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = crime_anal_norm['살인'],
               columns = [crime_anal_norm.index, crime_anal_norm['살인']],
               fill_color = 'PuRd', #PuRd, YlGnBu
               key_on = 'feature.id')
map
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tmp_criminal = crime_anal_norm['살인'] /  crime_anal_norm['인구수'] * 1000000

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, 
                 tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = tmp_criminal,
               columns = [crime_anal.index, tmp_criminal],
               fill_color = 'PuRd', #PuRd, YlGnBu
               key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_excel("02. sales-funnel.xlsx")

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
pd.pivot_table(df,index =['Name']) #Pivot 테이블의 Default는 각 칼럼의 평균치 = mean
# Out:
#                               Account   Price  Quantity
# Name
# Barton LLC                     740150   35000  1.000000
# Fritsch, Russel and Anderson   737550   35000  1.000000
# Herman LLC                     141962   65000  2.000000
# Jerde-Hilpert                  412290    5000  2.000000
# Kassulke, Ondricka and Metz    307599    7000  3.000000
# Keeling LLC                    688981  100000  5.000000
# Kiehn-Spinka                   146832   65000  2.000000
# Koepp Ltd                      729833   35000  2.000000
# Kulas Inc                      218895   25000  1.500000
# Purdy-Kunde                    163416   30000  1.000000
# Stokes LLC                     239344    7500  1.000000
# Trantow-Barrows                714466   15000  1.333333

# %%
pd.pivot_table(df,index =['Name', 'Rep', 'Manager']) #Pivot 테이블의 Default는 각 칼럼의 평균치 = mean
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# ...

# %%
pd.pivot_table(df,index =['Manager', 'Rep']) #노드의 그룹 -> 그룹화 ( 공통 매니저 -> 각 Rep)
# Out:
#                               Account         Price  Quantity
# Manager       Rep
# Debra Henley  Craig Booker   720237.0  20000.000000  1.250000
#               Daniel Hilton  194874.0  38333.333333  1.666667
#               John Smith     576220.0  20000.000000  1.500000
# Fred Anderson Cedric Moss    196016.5  27500.000000  1.250000
#               Wendy Yule     614061.5  44250.000000  3.000000

# %%
#Pivot 테이블은 정리 테이블이라고 불림, 수치화 할 수 있는 것은 다 보여줌

# %%
pd.pivot_table(df,index =['Manager', 'Rep'], values=['Price'])  #Values 는 하나만 보여줌
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
pd.pivot_table(df,index =['Manager', 'Rep'], values=['Price'], aggfunc=np.sum)  #합계치를 보여줌
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
pd.pivot_table(df,index =['Manager', 'Rep'], values=['Price'], aggfunc=[np.sum, len])  #합계치와 개수를 보여줌
# Out:
#                                 sum   len
#                               Price Price
# Manager       Rep
# Debra Henley  Craig Booker    80000     4
#               Daniel Hilton  115000     3
#               John Smith      40000     2
# Fred Anderson Cedric Moss    110000     4
#               Wendy Yule     177000     4

# %%
pd.pivot_table(df,index =['Manager', 'Rep'], values=['Price'], columns = ['Product'],aggfunc=[np.sum, len])  #합계치와 개수를 보여줌
# Out:
#                                   sum                                len  \
#                                 Price                              Price
# Product                           CPU Maintenance Monitor Software   CPU
# Manager       Rep
# Debra Henley  Craig Booker    65000.0      5000.0     NaN  10000.0   2.0
#               Daniel Hilton  105000.0         NaN     NaN  10000.0   2.0
#               John Smith      35000.0      5000.0     NaN      NaN   1.0
# Fred Anderson Cedric Moss     95000.0      5000.0     NaN  10000.0   2.0
#               Wendy Yule     165000.0      7000.0  5000.0      NaN   2.0
#
#
#
# Product                     Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker          1.0     NaN      1.0
#               Daniel Hilton         NaN     NaN      1.0
#               John Smith            1.0     NaN      NaN
# Fred Anderson Cedric Moss           1.0     NaN      1.0
# ...

# %%
pd.pivot_table(df,index =['Manager', 'Rep'], values=['Price'], columns = ['Product'],aggfunc=[np.sum, len], fill_value=0)
#fill_value = Nan 이 나왔을때 0 으로 처리
# Out:
#                                 sum                                len  \
#                               Price                              Price
# Product                         CPU Maintenance Monitor Software   CPU
# Manager       Rep
# Debra Henley  Craig Booker    65000        5000       0    10000     2
#               Daniel Hilton  105000           0       0    10000     2
#               John Smith      35000        5000       0        0     1
# Fred Anderson Cedric Moss     95000        5000       0    10000     2
#               Wendy Yule     165000        7000    5000        0     2
#
#
#
# Product                     Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker            1       0        1
#               Daniel Hilton           0       0        1
#               John Smith              1       0        0
# Fred Anderson Cedric Moss             1       0        1
#               Wendy Yule              1       1        0

# %%
#구별 범죄 총합
#구별 범죄 평균
crime_anal
# Out:
#       Unnamed: 0.1   강간  강도  살인    절도    폭력       강간검거율       강도검거율  \
# 구별
# 강남구             47  449  21  13  3850  4284   77.728285   85.714286
# 강동구             20  156   6   4  2366  2712   78.846154  100.000000
# 강북구             14  153  14   7  1434  2649   82.352941   92.857143
# 강서구             19  262  13   7  2096  3207   72.900763  100.000000
# 관악구             18  320  12   9  2706  3298   69.062500  100.000000
# 광진구             12  240  14   4  3026  2625   91.666667  100.000000
# 구로구             22  281  15   8  2335  3007   58.362989   73.333333
# 금천구             15  151   6   3  1567  2054   80.794702  100.000000
# 노원구             26  197   7  10  2193  2723   61.421320  100.000000
# 도봉구             29  102   9   3  1063  1487  100.000000  100.000000
# 동대문구             7  173  13   5  1981  2548   84.393064  100.000000
# 동작구             11  285   9   5  1865  1910   48.771930   55.555556
# 마포구              8  294  14   8  2555  2983   84.013605   71.428571
# ...

# %%
pd.pivot_table(crime_anal_norm,index =['구별'], values=['범죄']) #구별 범죄 평균
# Out:
#             범죄
# 구별
# 강남구   4.857843
# 강동구   1.286607
# 강북구   1.641616
# 강서구   2.333944
# 관악구   2.860342
# 광진구   2.204979
# 구로구   2.603930
# 금천구   0.666924
# 노원구   1.905445
# 도봉구   0.318627
# 동대문구  1.633921
# 동작구   1.451670
# 마포구   2.652927
# 서대문구  0.622036
# 서초구   2.464022
# 성동구   0.711008
# 성북구   0.905522
# 송파구   2.987821
# 양천구   0.856156
# 영등포구  3.983733
# 용산구   1.423080
# 은평구   1.225287
# 종로구   1.690786
# 중구    1.310920
# 중랑구   2.385443

# %%
#Seaborn = 기울기와 절편을 한번에 처리해버림

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
x = np.linspace(0, 14, 100)
#선으로 값을 쭉 표현하는 것 -> linear(선형) -> linearspace

# %%
y1 = np.sin(x)
y2 = 2 * np.sin(x + 0.5)

#사인곡선을 그리는 이유 : 주파수, 시계열, 시간에 따른 값의 흐름등을 구하기 위해서임.

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10, 6))
plt.plot(x, y1, x, y2)
plt.show()

# %%
tips = sns.load_dataset('tips') #seaborn에 있는 데이터셋 샘플 가져오긔
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (8, 6))
sns.boxplot(x = tips["total_bill"], data=tips)
plt.show()

#평균적인 금액은 10~30 사이임

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (8, 6))
sns.boxplot(x = "day", y = tips["total_bill"], data=tips)
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (8, 6))
sns.boxplot(x = "day", y = tips["total_bill"], hue='smoker', data=tips) #hue는 박스플롯 값의 항목을 나누어버림
plt.show()

#이 데이터는 boxplot 팁 값 -> 날짜별로 분류한 것 중에 -> hue로 흡연/비흡연자로 나눈것임

# %%
plt.figure(figsize = (8, 6))
sns.swarmplot(x = "day", y = "total_bill", data=tips, color="0.1")
sns.boxplot(x = "day", y = tips["total_bill"], data=tips)
plt.show()

# %%
#기울기와 절편을 구해서 한꺼번에 처리해주는애가 Seaborn에 존재함.

sns.set_style('darkgrid')
sns.lmplot(x = 'total_bill', y='tip', data=tips, size = 7 ) #lmplot 이란애가 알아서 기울기를 구해줌
plt.show()

#산점도와 선을 동시에 같이 그림
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#선을 찾았다는 것은 이 선을 기준으로 판단을 해야함
# 기울기는 '지표' 와 같이 해석하자.
# ex) 30 달러정도 total bill 이 나왔을때, 4달러 tip을 주는 것이 적정함

#기울기와 절편을 구해서 한꺼번에 처리해주는애가 Seaborn에 존재함.

sns.lmplot(x = 'total_bill', y='tip', hue="smoker", data=tips, size = 7 ) #lmplot 이란애가 알아서 기울기를 구해줌
plt.show()

#산점도와 선을 동시에 같이 그림
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
uniform_data = np.random.rand(10,12)
uniform_data
# Out:
# array([[9.95329005e-01, 8.78418610e-01, 2.31127366e-01, 8.96360827e-01,
#         4.88948295e-01, 4.81293032e-02, 5.14365221e-01, 1.68353064e-01,
#         4.08718325e-01, 6.46736254e-01, 4.73812339e-01, 7.76012469e-01],
#        [5.89940475e-02, 2.81617988e-01, 6.19502925e-01, 7.68904252e-01,
#         4.32088103e-01, 4.32243825e-01, 9.60333490e-02, 6.96077399e-01,
#         7.78536469e-01, 2.02011781e-01, 6.95924429e-01, 5.63600487e-01],
#        [2.60483986e-01, 2.94846019e-01, 8.83962439e-01, 1.48148544e-01,
#         6.47422913e-01, 1.41390344e-01, 2.29361758e-02, 2.11328136e-02,
#         4.55035972e-01, 6.60752224e-01, 7.54571529e-01, 4.45641875e-01],
#        [6.11486823e-01, 6.31718380e-01, 8.35275664e-01, 7.19416809e-01,
#         6.84555294e-01, 9.23806684e-02, 2.02892289e-01, 4.21922238e-01,
#         8.53987603e-01, 7.83050768e-01, 2.44047994e-01, 4.34624601e-01],
#        [8.75214610e-01, 4.14288995e-01, 4.32664986e-01, 6.94841208e-01,
# ...

# %%
sns.heatmap(uniform_data)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(uniform_data, annot=True, fmt="f")
plt.show()

# %%
#heatmap은 상관계수를 구할떄 사용했었음

# %%
sns.set(style='ticks')
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#상관이 없는 항목은 제거
#상관이 있는 항목만 추출

# %%
sns.pairplot(iris) #pairplot - > 상관짝궁 분석
plt.show()

# %%
sns.pairplot(iris, hue='species') #hue-> group by 개념 / 같은 그룹끼리 나누어줌
plt.show()

# %%
#왼쪽 하단 4개만 뽑아냄.
sns.pairplot(iris, x_vars = ['sepal_width', 'sepal_length'], 
             y_vars=['petal_width', 'petal_length'], hue='species')
plt.show()

# %%
crime_anal_norm
# Out:
#             강간        강도        살인        절도        폭력       강간검거율  \
# 구별
# 강남구   1.000000  0.941176  0.916667  1.000000  1.000000   77.728285
# 강동구   0.155620  0.058824  0.166667  0.467528  0.437969   78.846154
# 강북구   0.146974  0.529412  0.416667  0.133118  0.415445   82.352941
# 강서구   0.461095  0.470588  0.416667  0.370649  0.614945   72.900763
# 관악구   0.628242  0.411765  0.583333  0.589523  0.647479   69.062500
# 광진구   0.397695  0.529412  0.166667  0.704342  0.406864   91.666667
# 구로구   0.515850  0.588235  0.500000  0.456405  0.543439   58.362989
# 금천구   0.141210  0.058824  0.083333  0.180840  0.202717   80.794702
# 노원구   0.273775  0.117647  0.666667  0.405454  0.441902   61.421320
# 도봉구   0.000000  0.235294  0.083333  0.000000  0.000000  100.000000
# 동대문구  0.204611  0.470588  0.250000  0.329386  0.379335   84.393064
# 동작구   0.527378  0.235294  0.250000  0.287765  0.151233   48.771930
# 마포구   0.553314  0.529412  0.500000  0.535343  0.534859   84.013605
# ...

# %%
#한글깨지는거

#폰트 및 글자 한글 안깨지게 세팅

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
sns.pairplot(crime_anal_norm, vars=['강도', '살인', '폭력'], kind='reg') #kind = 선을 그어줌
plt.show()
#산점도를 찍어줌 -> 상관정도

# %%
# x 축은 인구수, CCTV
# y 축은 살인, 강도

sns.pairplot(crime_anal_norm, x_vars = ['인구수', 'CCTV'], 
             y_vars=['살인', '강도'], kind='reg')
plt.show()

##CCTV는 살인, 강도와 큰 상관이 없다
#인구수는 살인, 강도와 상관이 있다.

# %%
sns.pairplot(crime_anal_norm, x_vars = ['인구수', 'CCTV'], 
             y_vars=['폭력', '절도'], kind='reg')
plt.show()

#인구수가 CCTV보다 상관관계가 많다.

# %%
sns.pairplot(crime_anal_norm, x_vars = ['인구수', 'CCTV'], 
             y_vars=['살인검거율', '폭력검거율'], kind='reg')
plt.show()

#CCTV는 검거율과 상관이 없다.

# %%
sns.pairplot(crime_anal_norm, x_vars = ['인구수', 'CCTV'], 
             y_vars=['절도검거율', '강도검거율'], kind='reg')
plt.show()

#CCTV는 검거율과 상관이 없다.
